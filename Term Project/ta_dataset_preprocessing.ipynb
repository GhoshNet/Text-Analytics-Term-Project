# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import numpy as np

# %%
df = pd.read_csv("imdb62.csv")
df.head()
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
#
#                                                title  \
# 0                               Somebody call PETA !
# 1  Just Awful ! Mail Rosie a mussel to shut her b...
# 2                It's not for me ! I just hated it !
# 3  Rosie O'Donnell , Barbara Walters , What has t...
# 4               I thought the Kardashians were bad !
#
#                                              content
# 0  I caught glimpses of this show which feature a...
# 1  Believe it or not , I watched this show in the...
# 2  After only watching a few minutes of this adap...
# 3  I'm sorry but Rosie O'Donnell talking about he...
# 4  Okay , the reality show premise is five housew...

# %%
def remove_unicode(text):
    if isinstance(text, str):
        # Remove non-ASCII characters
        text = re.sub(r'[^\x00-\x7F]+', '', text)
    return text

# Step 2: Lowercasing
def to_lowercase(text):
    if isinstance(text, str):
        return text.lower()
    return text

# Apply to both columns
for col in ['title', 'content']:
    df[col] = df[col].apply(remove_unicode)
    df[col] = df[col].apply(to_lowercase)

# %% [markdown]
# # DATASET 1: BOTH STOPWORDS AND PUNCTUATION INCLUDED

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/parth/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/parth/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/parth/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /home/parth/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()

# Helper function to map POS tags to WordNet format
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # default to noun

# Tokenisation + Lemmatization
def tokenize_and_lemmatize(text):
    if isinstance(text, str):
        # Step 1: Tokenize
        tokens = word_tokenize(text)
        
        # Step 2: POS tagging for better lemmatization
        pos_tags = nltk.pos_tag(tokens)
        
        # Step 3: Lemmatize using POS tags
        lemmatized = [
            lemmatizer.lemmatize(word, get_wordnet_pos(tag))
            for word, tag in pos_tags
        ]
        
        return lemmatized  # returns a list of tokens
    return text

# Apply to both columns
for col in ['title', 'content']:
    df[col] = df[col].apply(tokenize_and_lemmatize)

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/parth/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
df.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                                title  \
# 0                          [somebody, call, peta, !]
# 1  [just, awful, !, mail, rosie, a, mussel, to, s...
# 2     [it, 's, not, for, me, !, i, just, hat, it, !]
# 3  [rosie, o'donnell, ,, barbara, walter, ,, what...
# 4           [i, think, the, kardashians, be, bad, !]
# 5              [why, brokeback, lose, the, oscar, ?]
# 6                [orwell, would, have, be, shock, !]
# 7                   [the, guide, to, parent, not, !]
# 8                             [just, a, disgrace, !]
# 9          [sorry, ,, this, be, n't, it, ,, seth, ?]
#
#                                              content
# 0  [i, catch, glimpse, of, this, show, which, fea...
# 1  [believe, it, or, not, ,, i, watch, this, show...
# 2  [after, only, watch, a, few, minute, of, this,...
# 3  [i, 'm, sorry, but, rosie, o'donnell, talk, ab...
# 4  [okay, ,, the, reality, show, premise, be, fiv...
# 5  [do, you, really, want, to, know, why, it, do,...
# 6  [i, do, n't, get, big, brother, ., i, read, ge...
# 7  [remember, robert, kardashian, ,, he, be, the,...
# 8  [i, try, to, like, will, and, grace, ., believ...
# 9  [i, love, seth, green, ., his, appearance, on,...

# %%
df.to_csv('imdb62_A.csv', index=False)

# %% [markdown]
# # DATASET 2: STOPWORDS REMOVED

# %%
df2 = pd.read_csv("imdb62.csv")
df2.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                                title  \
# 0                               Somebody call PETA !
# 1  Just Awful ! Mail Rosie a mussel to shut her b...
# 2                It's not for me ! I just hated it !
# 3  Rosie O'Donnell , Barbara Walters , What has t...
# 4               I thought the Kardashians were bad !
# 5                     Why Brokeback Lost the Oscar ?
# 6                   Orwell would have been shocked !
# 7                       The Guide to Parenting Not !
# 8                                  Just a Disgrace !
# 9                     Sorry , this isn't it , Seth ?
#
#                                              content
# 0  I caught glimpses of this show which feature a...
# 1  Believe it or not , I watched this show in the...
# 2  After only watching a few minutes of this adap...
# 3  I'm sorry but Rosie O'Donnell talking about he...
# 4  Okay , the reality show premise is five housew...
# 5  Do you really want to know why it didn't win t...
# 6  I don't get Big Brother . I read George Orwell...
# 7  Remember Robert Kardashian , he was the attorn...
# 8  I tried to like Will and Grace . Believe me I ...
# 9  I love Seth Green . His appearances on THat 70...

# %%
from nltk.corpus import stopwords

# Initialize
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

def preprocess(text):
    if isinstance(text, str):
        # Step 1: Remove Unicode strings
        text = re.sub(r'[^\x00-\x7F]+', '', text)
        
        # Step 2: Lowercase
        text = text.lower()
        
        # Step 3: Tokenize
        tokens = word_tokenize(text)
        
        # Step 4: Remove stopwords
        tokens = [t for t in tokens if t not in stop_words]
        
        # Step 5: Lemmatize
        pos_tags = nltk.pos_tag(tokens)
        tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags]
        
        return ' '.join(tokens)
    return text

df2['title'] = df2['title'].apply(preprocess)
df2['content'] = df2['content'].apply(preprocess)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/parth/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df2.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                             title  \
# 0                            somebody call peta !
# 1      awful ! mail rosie mussel shut big mouth !
# 2                                      's ! hat !
# 3  rosie o'donnell , barbara walter , show turn ?
# 4                       thought kardashians bad !
# 5                          brokeback lose oscar ?
# 6                            orwell would shock !
# 7                               guide parenting !
# 8                                      disgrace !
# 9                            sorry , n't , seth ?
#
#                                              content
# 0  caught glimpse show feature gay male couple do...
# 1  believe , watch show beginning 1996 fan . anym...
# 2  watch minute adaptation william shakespeare 's...
# 3  'm sorry rosie o'donnell talk mother 's death ...
# 4  okay , reality show premise five housewife new...
# 5  really want know n't win oscar ? well maybe pr...
# 6  n't get big brother . read george orwell 's no...
# 7  remember robert kardashian , attorney best fri...
# 8  try like grace . believe tried . always get wr...
# 9  love seth green . appearance 70 ' show always ...

# %%
df2.to_csv('imdb62_B.csv', index=False)

# %% [markdown]
# # DATASET 3: PUNTUATION REMOVED

# %%
df3 = pd.read_csv("imdb62.csv")

# %%
df3.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                                title  \
# 0                               Somebody call PETA !
# 1  Just Awful ! Mail Rosie a mussel to shut her b...
# 2                It's not for me ! I just hated it !
# 3  Rosie O'Donnell , Barbara Walters , What has t...
# 4               I thought the Kardashians were bad !
# 5                     Why Brokeback Lost the Oscar ?
# 6                   Orwell would have been shocked !
# 7                       The Guide to Parenting Not !
# 8                                  Just a Disgrace !
# 9                     Sorry , this isn't it , Seth ?
#
#                                              content
# 0  I caught glimpses of this show which feature a...
# 1  Believe it or not , I watched this show in the...
# 2  After only watching a few minutes of this adap...
# 3  I'm sorry but Rosie O'Donnell talking about he...
# 4  Okay , the reality show premise is five housew...
# 5  Do you really want to know why it didn't win t...
# 6  I don't get Big Brother . I read George Orwell...
# 7  Remember Robert Kardashian , he was the attorn...
# 8  I tried to like Will and Grace . Believe me I ...
# 9  I love Seth Green . His appearances on THat 70...

# %%
import string

lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

def preprocess(text):
    if isinstance(text, str):
        # Step 1: Remove Unicode strings
        text = re.sub(r'[^\x00-\x7F]+', '', text)
        
        # Step 2: Lowercase
        text = text.lower()
        
        # Step 3: Tokenize
        tokens = word_tokenize(text)
        
        # Step 4: Remove punctuation
        tokens = [t for t in tokens if t not in string.punctuation]
        
        # Step 5: Lemmatize
        pos_tags = nltk.pos_tag(tokens)
        tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags]
        
        return ' '.join(tokens)
    return text

# Apply to both columns
df3['title'] = df3['title'].apply(preprocess)
df3['content'] = df3['content'].apply(preprocess)

# %%
df3.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                                title  \
# 0                                 somebody call peta
# 1  just awful mail rosie a mussel to shut her big...
# 2                     it 's not for me i just hat it
# 3  rosie o'donnell barbara walter what have this ...
# 4                     i think the kardashians be bad
# 5                       why brokeback lose the oscar
# 6                         orwell would have be shock
# 7                            the guide to parent not
# 8                                    just a disgrace
# 9                          sorry this be n't it seth
#
#                                              content
# 0  i catch glimpse of this show which feature a g...
# 1  believe it or not i watch this show in the beg...
# 2  after only watch a few minute of this adaptati...
# 3  i 'm sorry but rosie o'donnell talk about her ...
# 4  okay the reality show premise be five housewif...
# 5  do you really want to know why it do n't win t...
# 6  i do n't get big brother i read george orwell ...
# 7  remember robert kardashian he be the attorney ...
# 8  i try to like will and grace believe me i try ...
# 9  i love seth green his appearance on that 70 sh...

# %%
df3.to_csv('imdb62_C.csv', index=False)

# %% [markdown]
# # DATASET 4: NO STOPWORDS AND PUNCTUATION

# %%
df4 = pd.read_csv("imdb62.csv")

# %%
df4.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                                title  \
# 0                               Somebody call PETA !
# 1  Just Awful ! Mail Rosie a mussel to shut her b...
# 2                It's not for me ! I just hated it !
# 3  Rosie O'Donnell , Barbara Walters , What has t...
# 4               I thought the Kardashians were bad !
# 5                     Why Brokeback Lost the Oscar ?
# 6                   Orwell would have been shocked !
# 7                       The Guide to Parenting Not !
# 8                                  Just a Disgrace !
# 9                     Sorry , this isn't it , Seth ?
#
#                                              content
# 0  I caught glimpses of this show which feature a...
# 1  Believe it or not , I watched this show in the...
# 2  After only watching a few minutes of this adap...
# 3  I'm sorry but Rosie O'Donnell talking about he...
# 4  Okay , the reality show premise is five housew...
# 5  Do you really want to know why it didn't win t...
# 6  I don't get Big Brother . I read George Orwell...
# 7  Remember Robert Kardashian , he was the attorn...
# 8  I tried to like Will and Grace . Believe me I ...
# 9  I love Seth Green . His appearances on THat 70...

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

def preprocess(text):
    if isinstance(text, str):
        # Step 1: Remove Unicode strings
        text = re.sub(r'[^\x00-\x7F]+', '', text)
        
        # Step 2: Lowercase
        text = text.lower()
        
        # Step 3: Tokenize
        tokens = word_tokenize(text)
        
        # Step 4: Remove punctuation and stopwords
        tokens = [t for t in tokens if t not in string.punctuation and t not in stop_words]
        
        # Step 5: Lemmatize
        pos_tags = nltk.pos_tag(tokens)
        tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags]
        
        return ' '.join(tokens)
    return text

# Apply to both columns
df4['title'] = df4['title'].apply(preprocess)
df4['content'] = df4['content'].apply(preprocess)

# %%
df4.head(10)
# Out:
#    reviewId  userId   itemId  rating  \
# 0    490485   33913   444584     1.0
# 1    490043   33913   123366     1.0
# 2    490772   33913   117509     1.0
# 3    490415   33913   169455     2.0
# 4    490180   33913  1191056     2.0
# 5    490230   33913   388795     2.0
# 6    489825   33913   257295     2.0
# 7    490100   33913  1086761     2.0
# 8    490337   33913   157246     2.0
# 9    490338   33913   461721     2.0
#
#                                       title  \
# 0                        somebody call peta
# 1    awful mail rosie mussel shut big mouth
# 2                                    's hat
# 3  rosie o'donnell barbara walter show turn
# 4                   thought kardashians bad
# 5                      brokeback lose oscar
# 6                        orwell would shock
# 7                           guide parenting
# 8                                  disgrace
# 9                            sorry n't seth
#
#                                              content
# 0  caught glimpse show feature gay male couple do...
# 1  believe watch show beginning 1996 fan anymore ...
# 2  watch minute adaptation william shakespeare 's...
# 3  'm sorry rosie o'donnell talk mother 's death ...
# 4  okay reality show premise five housewife new y...
# 5  really want know n't win oscar well maybe prio...
# 6  n't get big brother read george orwell 's nove...
# 7  remember robert kardashian attorney best frien...
# 8  try like grace believe try always get wrong im...
# 9  love seth green appearance 70 show always wort...

# %%
df4.to_csv('imdb62_D.csv', index=False)
